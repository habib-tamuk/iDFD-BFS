# %%
import time

start_time = time.time()

# Your code here
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report

# Load data from CSV file
data = pd.read_csv('data7L.csv')

# Split data into input features (X) and output variable (y)
X = data.drop('Output', axis=1)
y = data['Output']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Define models
models = {'Logistic Regression': LogisticRegression(max_iter=1000),
          'K-Nearest Neighbors': KNeighborsClassifier(),
          'Decision Tree': DecisionTreeClassifier(),
          'AdaBoost': AdaBoostClassifier(),
          'Random Forest': RandomForestClassifier(),
          'Support Vector Machine': SVC()}

# Train and evaluate models
for name, model in models.items():
    print(name)
    print('---')
    # Train classifier on training set
    model.fit(X_train, y_train)
    
    # Evaluate classifier on testing set
    score = model.score(X_test, y_test)
    print("Model score: ", score)
    
    # Predict output variable on testing set
    y_pred = model.predict(X_test)
    
    # Compute confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print('Confusion Matrix: \n',cm)
    
    # Compute classification report
    report = classification_report(y_test, y_pred)
    print("Classification report:\n", report)
    
    # Compute evaluation metrics
    testing_accuracy = cm.diagonal().sum() / cm.sum()
    sensitivity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
    specificity = cm[0, 0] / (cm[0, 1] + cm[0, 0])
    fpr = cm[0, 1] / (cm[0, 1] + cm[0, 0])
    fnr = cm[1, 0] / (cm[1, 0] + cm[1, 1])
    fdr = cm[0, 1] / (cm[0, 1] + cm[1, 1])
    npv = cm[0, 0] / (cm[0, 0] + cm[1, 0])
    
    # Print evaluation metrics
    print("Testing accuracy: ", testing_accuracy)
    print("Sensitivity: ", sensitivity)
    print("Specificity: ", specificity)
    print("False positive rate: ", fpr)
    print("False negative rate: ", fnr)
    print("False discovery rate: ", fdr)
    print("Negative predictive value: ", npv)
    print('---\n')



end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Logistic Regression
# ---
# Model score:  0.7530864197530864
# Confusion Matrix:
#  [[34  8]
#  [12 27]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77        42
#            1       0.77      0.69      0.73        39
#
#     accuracy                           0.75        81
#    macro avg       0.76      0.75      0.75        81
# weighted avg       0.75      0.75      0.75        81
#
# Testing accuracy:  0.7530864197530864
# Sensitivity:  0.6923076923076923
# Specificity:  0.8095238095238095
# False positive rate:  0.19047619047619047
# False negative rate:  0.3076923076923077
# False discovery rate:  0.22857142857142856
# Negative predictive value:  0.7391304347826086
# ---
#
# K-Nearest Neighbors
# ---
# Model score:  0.6172839506172839
# Confusion Matrix:
#  [[27 15]
#  [16 23]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.64      0.64        42
#            1       0.61      0.59      0.60        39
#
#     accuracy                           0.62        81
#    macro avg       0.62      0.62      0.62        81
# weighted avg       0.62      0.62      0.62        81
#
# Testing accuracy:  0.6172839506172839
# Sensitivity:  0.5897435897435898
# Specificity:  0.6428571428571429
# False positive rate:  0.35714285714285715
# False negative rate:  0.41025641025641024
# False discovery rate:  0.39473684210526316
# Negative predictive value:  0.627906976744186
# ---
#
# Decision Tree
# ---
# Model score:  0.8765432098765432
# Confusion Matrix:
#  [[38  4]
#  [ 6 33]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        42
#            1       0.89      0.85      0.87        39
#
#     accuracy                           0.88        81
#    macro avg       0.88      0.88      0.88        81
# weighted avg       0.88      0.88      0.88        81
#
# Testing accuracy:  0.8765432098765432
# Sensitivity:  0.8461538461538461
# Specificity:  0.9047619047619048
# False positive rate:  0.09523809523809523
# False negative rate:  0.15384615384615385
# False discovery rate:  0.10810810810810811
# Negative predictive value:  0.8636363636363636
# ---
#
# AdaBoost
# ---
# Model score:  0.8641975308641975
# Confusion Matrix:
#  [[37  5]
#  [ 6 33]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87        42
#            1       0.87      0.85      0.86        39
#
#     accuracy                           0.86        81
#    macro avg       0.86      0.86      0.86        81
# weighted avg       0.86      0.86      0.86        81
#
# Testing accuracy:  0.8641975308641975
# Sensitivity:  0.8461538461538461
# Specificity:  0.8809523809523809
# False positive rate:  0.11904761904761904
# False negative rate:  0.15384615384615385
# False discovery rate:  0.13157894736842105
# Negative predictive value:  0.8604651162790697
# ---
#
# Random Forest
# ---
# Model score:  0.9012345679012346
# Confusion Matrix:
#  [[38  4]
#  [ 4 35]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        42
#            1       0.90      0.90      0.90        39
#
#     accuracy                           0.90        81
#    macro avg       0.90      0.90      0.90        81
# weighted avg       0.90      0.90      0.90        81
#
# Testing accuracy:  0.9012345679012346
# Sensitivity:  0.8974358974358975
# Specificity:  0.9047619047619048
# False positive rate:  0.09523809523809523
# False negative rate:  0.10256410256410256
# False discovery rate:  0.10256410256410256
# Negative predictive value:  0.9047619047619048
# ---
#
# Support Vector Machine
# ---
# Model score:  0.6049382716049383
# Confusion Matrix:
#  [[16 26]
#  [ 6 33]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.38      0.50        42
#            1       0.56      0.85      0.67        39
#
#     accuracy                           0.60        81
#    macro avg       0.64      0.61      0.59        81
# weighted avg       0.65      0.60      0.58        81
#
# Testing accuracy:  0.6049382716049383
# Sensitivity:  0.8461538461538461
# Specificity:  0.38095238095238093
# False positive rate:  0.6190476190476191
# False negative rate:  0.15384615384615385
# False discovery rate:  0.4406779661016949
# Negative predictive value:  0.7272727272727273
# ---
#
# Elapsed time: 0.9693012237548828 seconds

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Define models
models = {'Logistic Regression': LogisticRegression(max_iter=1000),
          'K-Nearest Neighbors': KNeighborsClassifier(),
          'Decision Tree': DecisionTreeClassifier(),
          'AdaBoost': AdaBoostClassifier(),
          'Random Forest': RandomForestClassifier(),
          'Support Vector Machine': SVC(probability=True)}

# Plot ROC curve for all models
for name, model in models.items():
    print(name)
    print('---')
    # Train classifier on training set
    model.fit(X_train, y_train)

    # Compute predicted probabilities for testing set
    y_prob = model.predict_proba(X_test)[:, 1]

    # Compute false positive rate, true positive rate, and threshold
    fpr, tpr, threshold = roc_curve(y_test, y_prob)
    
    # Compute area under the curve
    roc_auc = auc(fpr, tpr)
    
    # Plot ROC curve
    plt.plot(fpr, tpr, label='{} (AUC = {:.2f})'.format(name, roc_auc))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0, 1])
plt.ylim([0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Logistic Regression
# ---
# K-Nearest Neighbors
# ---
# Decision Tree
# ---
# AdaBoost
# ---
# Random Forest
# ---
# Support Vector Machine
# ---
